# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import io
import imageio
from IPython.display import Image, display
from ipywidgets import widgets, Layout, HBox

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Download and load the dataset.
"""
fpath = keras.utils.get_file(
    "moving_mnist.npy",
    "http://www.cs.toronto.edu/~nitish/unsupervised_video/mnist_test_seq.npy",
)
"""
fpath = "/content/drive/MyDrive/PBL_Shared_Data/202101cldcrop64.npy"
dataset = np.load(fpath)

# Swap the axes representing the number of frames and number of data samples.
dataset = np.swapaxes(dataset, 0, 1)
# We'll pick out 1000 of the 10000 total examples and use those.
dataset = dataset[:1000, ...]
# Add a channel dimension since the images are grayscale.
dataset = np.expand_dims(dataset, axis=-1)

# Split into train and validation sets using indexing to optimize memory.
indexes = np.arange(dataset.shape[0])
np.random.shuffle(indexes)
train_index = indexes[: int(0.9 * dataset.shape[0])]
val_index = indexes[int(0.9 * dataset.shape[0]) :]
train_dataset = dataset[train_index]
val_dataset = dataset[val_index]

# Normalize the data to the 0-1 range.
train_dataset = train_dataset / 255
val_dataset = val_dataset / 255

# We'll define a helper function to shift the frames, where
# `x` is frames 0 to n - 1, and `y` is frames 1 to n.
def create_shifted_frames(data):
    x = data[:, 0 : data.shape[1] - 1, :, :]
    y = data[:, 1 : data.shape[1], :, :]
    return x, y


# Apply the processing function to the datasets.
x_train, y_train = create_shifted_frames(train_dataset)
x_val, y_val = create_shifted_frames(val_dataset)

# Inspect the dataset.
print("Training Dataset Shapes: " + str(x_train.shape) + ", " + str(y_train.shape))
print("Validation Dataset Shapes: " + str(x_val.shape) + ", " + str(y_val.shape))
# Out:
# Training Dataset Shapes: (27, 23, 64, 64, 1), (27, 23, 64, 64, 1)
# Validation Dataset Shapes: (3, 23, 64, 64, 1), (3, 23, 64, 64, 1)

# %%
# Construct a figure on which we will visualize the images.
fig, axes = plt.subplots(4, 6, figsize=(10, 8))

# Plot each of the sequential images for one random data example.
data_choice = np.random.choice(range(len(train_dataset)), size=1)[0]
for idx, ax in enumerate(axes.flat):
    ax.imshow(np.squeeze(train_dataset[data_choice][idx]), cmap="gray")
    ax.set_title(f"Frame {idx + 1}")
    ax.axis("off")

# Print information and display the figure.
print(f"Displaying frames for example {data_choice}.")
plt.show()
# Out:
# Displaying frames for example 5.

# %%
np.__version__
# Out:
# '1.21.6'

# %%
# Construct the input layer with no definite frame size.
inp = layers.Input(shape=(None, *x_train.shape[2:]))
fs = 64
# We will construct 3 `ConvLSTM2D` layers with batch normalization,
# followed by a `Conv3D` layer for the spatiotemporal outputs.
x = layers.ConvLSTM2D(
    filters=fs,
    kernel_size=(5, 5),
    padding="same",
    return_sequences=True,
    activation="relu",
)(inp)
x = layers.BatchNormalization()(x)
x = layers.ConvLSTM2D(
    filters=fs,
    kernel_size=(3, 3),
    padding="same",
    return_sequences=True,
    activation="relu",
)(x)
x = layers.BatchNormalization()(x)
x = layers.ConvLSTM2D(
    filters=fs,
    kernel_size=(1, 1),
    padding="same",
    return_sequences=True,
    activation="relu",
)(x)
x = layers.Conv3D(
    filters=1, kernel_size=(3, 3, 3), activation="sigmoid", padding="same"
)(x)

# Next, we will build the complete model and compile it.
model = keras.models.Model(inp, x)
model.compile(
    loss=keras.losses.binary_crossentropy, optimizer=keras.optimizers.Adam(),
)

# %%
# Define some callbacks to improve training.
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=5)

# Define modifiable training hyperparameters.
epochs = 200
batch_size = 5

# Fit the model to the training data.
model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_val, y_val),
    callbacks=[early_stopping, reduce_lr],
)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 25s 1s/step - loss: 0.5447 - val_loss: 0.6879 - lr: 0.0010
# Epoch 2/200
# 6/6 [==============================] - 6s 914ms/step - loss: 0.3735 - val_loss: 0.6803 - lr: 0.0010
# Epoch 3/200
# 6/6 [==============================] - 6s 917ms/step - loss: 0.2546 - val_loss: 0.6712 - lr: 0.0010
# Epoch 4/200
# 6/6 [==============================] - 6s 917ms/step - loss: 0.2219 - val_loss: 0.6649 - lr: 0.0010
# Epoch 5/200
# 6/6 [==============================] - 6s 928ms/step - loss: 0.2106 - val_loss: 0.6607 - lr: 0.0010
# Epoch 6/200
# 6/6 [==============================] - 6s 934ms/step - loss: 0.2006 - val_loss: 0.6592 - lr: 0.0010
# Epoch 7/200
# 6/6 [==============================] - 6s 934ms/step - loss: 0.1905 - val_loss: 0.6598 - lr: 0.0010
# Epoch 8/200
# 6/6 [==============================] - 6s 940ms/step - loss: 0.1788 - val_loss: 0.6620 - lr: 0.0010
# Epoch 9/200
# 6/6 [==============================] - 6s 952ms/step - loss: 0.1671 - val_loss: 0.6631 - lr: 0.0010
# Epoch 10/200
# 6/6 [==============================] - 6s 945ms/step - loss: 0.1599 - val_loss: 0.6622 - lr: 0.0010
# Epoch 11/200
# 6/6 [==============================] - 6s 961ms/step - loss: 0.1538 - val_loss: 0.6614 - lr: 0.0010
# Epoch 12/200
# 6/6 [==============================] - 6s 954ms/step - loss: 0.1501 - val_loss: 0.6592 - lr: 1.0000e-04
# Epoch 13/200
# 6/6 [==============================] - 6s 963ms/step - loss: 0.1492 - val_loss: 0.6577 - lr: 1.0000e-04
# Epoch 14/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1483 - val_loss: 0.6555 - lr: 1.0000e-04
# Epoch 15/200
# 6/6 [==============================] - 6s 970ms/step - loss: 0.1475 - val_loss: 0.6540 - lr: 1.0000e-04
# Epoch 16/200
# 6/6 [==============================] - 6s 980ms/step - loss: 0.1467 - val_loss: 0.6517 - lr: 1.0000e-04
# Epoch 17/200
# 6/6 [==============================] - 6s 988ms/step - loss: 0.1459 - val_loss: 0.6501 - lr: 1.0000e-04
# Epoch 18/200
# 6/6 [==============================] - 6s 988ms/step - loss: 0.1451 - val_loss: 0.6479 - lr: 1.0000e-04
# Epoch 19/200
# 6/6 [==============================] - 6s 988ms/step - loss: 0.1443 - val_loss: 0.6459 - lr: 1.0000e-04
# Epoch 20/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1435 - val_loss: 0.6438 - lr: 1.0000e-04
# Epoch 21/200
# 6/6 [==============================] - 7s 1s/step - loss: 0.1426 - val_loss: 0.6416 - lr: 1.0000e-04
# Epoch 22/200
# 6/6 [==============================] - 6s 983ms/step - loss: 0.1417 - val_loss: 0.6394 - lr: 1.0000e-04
# Epoch 23/200
# 6/6 [==============================] - 6s 967ms/step - loss: 0.1408 - val_loss: 0.6371 - lr: 1.0000e-04
# Epoch 24/200
# 6/6 [==============================] - 6s 966ms/step - loss: 0.1399 - val_loss: 0.6348 - lr: 1.0000e-04
# Epoch 25/200
# 6/6 [==============================] - 6s 963ms/step - loss: 0.1390 - val_loss: 0.6324 - lr: 1.0000e-04
# Epoch 26/200
# 6/6 [==============================] - 6s 979ms/step - loss: 0.1380 - val_loss: 0.6299 - lr: 1.0000e-04
# Epoch 27/200
# 6/6 [==============================] - 6s 969ms/step - loss: 0.1370 - val_loss: 0.6273 - lr: 1.0000e-04
# Epoch 28/200
# 6/6 [==============================] - 6s 968ms/step - loss: 0.1360 - val_loss: 0.6245 - lr: 1.0000e-04
# Epoch 29/200
# 6/6 [==============================] - 6s 976ms/step - loss: 0.1350 - val_loss: 0.6218 - lr: 1.0000e-04
# Epoch 30/200
# 6/6 [==============================] - 6s 990ms/step - loss: 0.1340 - val_loss: 0.6189 - lr: 1.0000e-04
# Epoch 31/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1330 - val_loss: 0.6159 - lr: 1.0000e-04
# Epoch 32/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1319 - val_loss: 0.6128 - lr: 1.0000e-04
# Epoch 33/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1309 - val_loss: 0.6094 - lr: 1.0000e-04
# Epoch 34/200
# 6/6 [==============================] - 6s 981ms/step - loss: 0.1299 - val_loss: 0.6058 - lr: 1.0000e-04
# Epoch 35/200
# 6/6 [==============================] - 6s 979ms/step - loss: 0.1288 - val_loss: 0.6020 - lr: 1.0000e-04
# Epoch 36/200
# 6/6 [==============================] - 6s 967ms/step - loss: 0.1278 - val_loss: 0.5983 - lr: 1.0000e-04
# Epoch 37/200
# 6/6 [==============================] - 6s 973ms/step - loss: 0.1268 - val_loss: 0.5942 - lr: 1.0000e-04
# Epoch 38/200
# 6/6 [==============================] - 6s 976ms/step - loss: 0.1258 - val_loss: 0.5900 - lr: 1.0000e-04
# Epoch 39/200
# 6/6 [==============================] - 6s 970ms/step - loss: 0.1248 - val_loss: 0.5856 - lr: 1.0000e-04
# Epoch 40/200
# 6/6 [==============================] - 6s 969ms/step - loss: 0.1239 - val_loss: 0.5809 - lr: 1.0000e-04
# Epoch 41/200
# 6/6 [==============================] - 6s 971ms/step - loss: 0.1230 - val_loss: 0.5769 - lr: 1.0000e-04
# Epoch 42/200
# 6/6 [==============================] - 6s 982ms/step - loss: 0.1221 - val_loss: 0.5720 - lr: 1.0000e-04
# Epoch 43/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1213 - val_loss: 0.5675 - lr: 1.0000e-04
# Epoch 44/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1205 - val_loss: 0.5628 - lr: 1.0000e-04
# Epoch 45/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1197 - val_loss: 0.5583 - lr: 1.0000e-04
# Epoch 46/200
# 6/6 [==============================] - 6s 976ms/step - loss: 0.1189 - val_loss: 0.5531 - lr: 1.0000e-04
# Epoch 47/200
# 6/6 [==============================] - 6s 969ms/step - loss: 0.1182 - val_loss: 0.5481 - lr: 1.0000e-04
# Epoch 48/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1174 - val_loss: 0.5428 - lr: 1.0000e-04
# Epoch 49/200
# 6/6 [==============================] - 6s 976ms/step - loss: 0.1167 - val_loss: 0.5368 - lr: 1.0000e-04
# Epoch 50/200
# 6/6 [==============================] - 6s 979ms/step - loss: 0.1161 - val_loss: 0.5304 - lr: 1.0000e-04
# Epoch 51/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1155 - val_loss: 0.5243 - lr: 1.0000e-04
# Epoch 52/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1149 - val_loss: 0.5169 - lr: 1.0000e-04
# Epoch 53/200
# 6/6 [==============================] - 6s 969ms/step - loss: 0.1143 - val_loss: 0.5107 - lr: 1.0000e-04
# Epoch 54/200
# 6/6 [==============================] - 7s 1s/step - loss: 0.1138 - val_loss: 0.5022 - lr: 1.0000e-04
# Epoch 55/200
# 6/6 [==============================] - 6s 967ms/step - loss: 0.1134 - val_loss: 0.4955 - lr: 1.0000e-04
# Epoch 56/200
# 6/6 [==============================] - 6s 967ms/step - loss: 0.1129 - val_loss: 0.4875 - lr: 1.0000e-04
# Epoch 57/200
# 6/6 [==============================] - 6s 976ms/step - loss: 0.1125 - val_loss: 0.4763 - lr: 1.0000e-04
# Epoch 58/200
# 6/6 [==============================] - 6s 967ms/step - loss: 0.1121 - val_loss: 0.4678 - lr: 1.0000e-04
# Epoch 59/200
# 6/6 [==============================] - 6s 973ms/step - loss: 0.1117 - val_loss: 0.4578 - lr: 1.0000e-04
# Epoch 60/200
# 6/6 [==============================] - 6s 979ms/step - loss: 0.1113 - val_loss: 0.4488 - lr: 1.0000e-04
# Epoch 61/200
# 6/6 [==============================] - 6s 973ms/step - loss: 0.1112 - val_loss: 0.4395 - lr: 1.0000e-04
# Epoch 62/200
# 6/6 [==============================] - 6s 979ms/step - loss: 0.1109 - val_loss: 0.4281 - lr: 1.0000e-04
# Epoch 63/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1106 - val_loss: 0.4158 - lr: 1.0000e-04
# Epoch 64/200
# 6/6 [==============================] - 6s 983ms/step - loss: 0.1103 - val_loss: 0.4051 - lr: 1.0000e-04
# Epoch 65/200
# 6/6 [==============================] - 6s 992ms/step - loss: 0.1100 - val_loss: 0.3940 - lr: 1.0000e-04
# Epoch 66/200
# 6/6 [==============================] - 6s 973ms/step - loss: 0.1097 - val_loss: 0.3835 - lr: 1.0000e-04
# Epoch 67/200
# 6/6 [==============================] - 6s 978ms/step - loss: 0.1094 - val_loss: 0.3740 - lr: 1.0000e-04
# Epoch 68/200
# 6/6 [==============================] - 6s 970ms/step - loss: 0.1092 - val_loss: 0.3634 - lr: 1.0000e-04
# Epoch 69/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1089 - val_loss: 0.3534 - lr: 1.0000e-04
# Epoch 70/200
# 6/6 [==============================] - 6s 967ms/step - loss: 0.1087 - val_loss: 0.3432 - lr: 1.0000e-04
# Epoch 71/200
# 6/6 [==============================] - 6s 970ms/step - loss: 0.1085 - val_loss: 0.3334 - lr: 1.0000e-04
# Epoch 72/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1083 - val_loss: 0.3242 - lr: 1.0000e-04
# Epoch 73/200
# 6/6 [==============================] - 6s 977ms/step - loss: 0.1082 - val_loss: 0.3132 - lr: 1.0000e-04
# Epoch 74/200
# 6/6 [==============================] - 6s 963ms/step - loss: 0.1080 - val_loss: 0.2997 - lr: 1.0000e-04
# Epoch 75/200
# 6/6 [==============================] - 6s 965ms/step - loss: 0.1081 - val_loss: 0.2860 - lr: 1.0000e-04
# Epoch 76/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1079 - val_loss: 0.2748 - lr: 1.0000e-04
# Epoch 77/200
# 6/6 [==============================] - 6s 977ms/step - loss: 0.1076 - val_loss: 0.2687 - lr: 1.0000e-04
# Epoch 78/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1074 - val_loss: 0.2572 - lr: 1.0000e-04
# Epoch 79/200
# 6/6 [==============================] - 6s 969ms/step - loss: 0.1072 - val_loss: 0.2495 - lr: 1.0000e-04
# Epoch 80/200
# 6/6 [==============================] - 6s 978ms/step - loss: 0.1070 - val_loss: 0.2406 - lr: 1.0000e-04
# Epoch 81/200
# 6/6 [==============================] - 6s 981ms/step - loss: 0.1068 - val_loss: 0.2335 - lr: 1.0000e-04
# Epoch 82/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1067 - val_loss: 0.2257 - lr: 1.0000e-04
# Epoch 83/200
# 6/6 [==============================] - 6s 967ms/step - loss: 0.1066 - val_loss: 0.2187 - lr: 1.0000e-04
# Epoch 84/200
# 6/6 [==============================] - 6s 978ms/step - loss: 0.1066 - val_loss: 0.2110 - lr: 1.0000e-04
# Epoch 85/200
# 6/6 [==============================] - 6s 991ms/step - loss: 0.1064 - val_loss: 0.2055 - lr: 1.0000e-04
# Epoch 86/200
# 6/6 [==============================] - 6s 973ms/step - loss: 0.1063 - val_loss: 0.1977 - lr: 1.0000e-04
# Epoch 87/200
# 6/6 [==============================] - 6s 973ms/step - loss: 0.1061 - val_loss: 0.1912 - lr: 1.0000e-04
# Epoch 88/200
# 6/6 [==============================] - 7s 1s/step - loss: 0.1060 - val_loss: 0.1885 - lr: 1.0000e-04
# Epoch 89/200
# 6/6 [==============================] - 6s 966ms/step - loss: 0.1059 - val_loss: 0.1809 - lr: 1.0000e-04
# Epoch 90/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1057 - val_loss: 0.1779 - lr: 1.0000e-04
# Epoch 91/200
# 6/6 [==============================] - 6s 977ms/step - loss: 0.1057 - val_loss: 0.1720 - lr: 1.0000e-04
# Epoch 92/200
# 6/6 [==============================] - 6s 977ms/step - loss: 0.1057 - val_loss: 0.1665 - lr: 1.0000e-04
# Epoch 93/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1055 - val_loss: 0.1634 - lr: 1.0000e-04
# Epoch 94/200
# 6/6 [==============================] - 6s 971ms/step - loss: 0.1054 - val_loss: 0.1619 - lr: 1.0000e-04
# Epoch 95/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1053 - val_loss: 0.1572 - lr: 1.0000e-04
# Epoch 96/200
# 6/6 [==============================] - 6s 982ms/step - loss: 0.1052 - val_loss: 0.1558 - lr: 1.0000e-04
# Epoch 97/200
# 6/6 [==============================] - 6s 970ms/step - loss: 0.1051 - val_loss: 0.1487 - lr: 1.0000e-04
# Epoch 98/200
# 6/6 [==============================] - 6s 976ms/step - loss: 0.1050 - val_loss: 0.1453 - lr: 1.0000e-04
# Epoch 99/200
# 6/6 [==============================] - 6s 976ms/step - loss: 0.1050 - val_loss: 0.1406 - lr: 1.0000e-04
# Epoch 100/200
# 6/6 [==============================] - 6s 978ms/step - loss: 0.1049 - val_loss: 0.1450 - lr: 1.0000e-04
# Epoch 101/200
# 6/6 [==============================] - 6s 983ms/step - loss: 0.1048 - val_loss: 0.1352 - lr: 1.0000e-04
# Epoch 102/200
# 6/6 [==============================] - 6s 980ms/step - loss: 0.1047 - val_loss: 0.1380 - lr: 1.0000e-04
# Epoch 103/200
# 6/6 [==============================] - 6s 970ms/step - loss: 0.1047 - val_loss: 0.1328 - lr: 1.0000e-04
# Epoch 104/200
# 6/6 [==============================] - 6s 976ms/step - loss: 0.1046 - val_loss: 0.1308 - lr: 1.0000e-04
# Epoch 105/200
# 6/6 [==============================] - 6s 980ms/step - loss: 0.1045 - val_loss: 0.1274 - lr: 1.0000e-04
# Epoch 106/200
# 6/6 [==============================] - 6s 976ms/step - loss: 0.1045 - val_loss: 0.1300 - lr: 1.0000e-04
# Epoch 107/200
# 6/6 [==============================] - 6s 978ms/step - loss: 0.1044 - val_loss: 0.1274 - lr: 1.0000e-04
# Epoch 108/200
# 6/6 [==============================] - 6s 982ms/step - loss: 0.1043 - val_loss: 0.1238 - lr: 1.0000e-04
# Epoch 109/200
# 6/6 [==============================] - 6s 985ms/step - loss: 0.1043 - val_loss: 0.1207 - lr: 1.0000e-04
# Epoch 110/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1042 - val_loss: 0.1233 - lr: 1.0000e-04
# Epoch 111/200
# 6/6 [==============================] - 6s 971ms/step - loss: 0.1041 - val_loss: 0.1213 - lr: 1.0000e-04
# Epoch 112/200
# 6/6 [==============================] - 6s 977ms/step - loss: 0.1041 - val_loss: 0.1223 - lr: 1.0000e-04
# Epoch 113/200
# 6/6 [==============================] - 6s 978ms/step - loss: 0.1040 - val_loss: 0.1163 - lr: 1.0000e-04
# Epoch 114/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1040 - val_loss: 0.1197 - lr: 1.0000e-04
# Epoch 115/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1039 - val_loss: 0.1150 - lr: 1.0000e-04
# Epoch 116/200
# 6/6 [==============================] - 6s 979ms/step - loss: 0.1039 - val_loss: 0.1148 - lr: 1.0000e-04
# Epoch 117/200
# 6/6 [==============================] - 6s 977ms/step - loss: 0.1038 - val_loss: 0.1147 - lr: 1.0000e-04
# Epoch 118/200
# 6/6 [==============================] - 6s 973ms/step - loss: 0.1037 - val_loss: 0.1162 - lr: 1.0000e-04
# Epoch 119/200
# 6/6 [==============================] - 6s 973ms/step - loss: 0.1037 - val_loss: 0.1162 - lr: 1.0000e-04
# Epoch 120/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1037 - val_loss: 0.1116 - lr: 1.0000e-04
# Epoch 121/200
# 6/6 [==============================] - 6s 980ms/step - loss: 0.1036 - val_loss: 0.1104 - lr: 1.0000e-04
# Epoch 122/200
# 6/6 [==============================] - 6s 1s/step - loss: 0.1036 - val_loss: 0.1099 - lr: 1.0000e-04
# Epoch 123/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1035 - val_loss: 0.1138 - lr: 1.0000e-04
# Epoch 124/200
# 6/6 [==============================] - 6s 968ms/step - loss: 0.1035 - val_loss: 0.1097 - lr: 1.0000e-04
# Epoch 125/200
# 6/6 [==============================] - 6s 980ms/step - loss: 0.1034 - val_loss: 0.1085 - lr: 1.0000e-04
# Epoch 126/200
# 6/6 [==============================] - 6s 970ms/step - loss: 0.1034 - val_loss: 0.1079 - lr: 1.0000e-04
# Epoch 127/200
# 6/6 [==============================] - 6s 978ms/step - loss: 0.1034 - val_loss: 0.1097 - lr: 1.0000e-04
# Epoch 128/200
# 6/6 [==============================] - 6s 973ms/step - loss: 0.1033 - val_loss: 0.1083 - lr: 1.0000e-04
# Epoch 129/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1033 - val_loss: 0.1069 - lr: 1.0000e-04
# Epoch 130/200
# 6/6 [==============================] - 6s 973ms/step - loss: 0.1032 - val_loss: 0.1071 - lr: 1.0000e-04
# Epoch 131/200
# 6/6 [==============================] - 6s 983ms/step - loss: 0.1032 - val_loss: 0.1078 - lr: 1.0000e-04
# Epoch 132/200
# 6/6 [==============================] - 6s 969ms/step - loss: 0.1034 - val_loss: 0.1077 - lr: 1.0000e-04
# Epoch 133/200
# 6/6 [==============================] - 6s 965ms/step - loss: 0.1033 - val_loss: 0.1083 - lr: 1.0000e-04
# Epoch 134/200
# 6/6 [==============================] - 6s 979ms/step - loss: 0.1033 - val_loss: 0.1053 - lr: 1.0000e-04
# Epoch 135/200
# 6/6 [==============================] - 6s 971ms/step - loss: 0.1033 - val_loss: 0.1052 - lr: 1.0000e-04
# Epoch 136/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1033 - val_loss: 0.1078 - lr: 1.0000e-04
# Epoch 137/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1032 - val_loss: 0.1054 - lr: 1.0000e-04
# Epoch 138/200
# 6/6 [==============================] - 6s 969ms/step - loss: 0.1030 - val_loss: 0.1049 - lr: 1.0000e-04
# Epoch 139/200
# 6/6 [==============================] - 6s 979ms/step - loss: 0.1030 - val_loss: 0.1049 - lr: 1.0000e-04
# Epoch 140/200
# 6/6 [==============================] - 6s 973ms/step - loss: 0.1029 - val_loss: 0.1050 - lr: 1.0000e-04
# Epoch 141/200
# 6/6 [==============================] - 6s 982ms/step - loss: 0.1028 - val_loss: 0.1046 - lr: 1.0000e-04
# Epoch 142/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1028 - val_loss: 0.1049 - lr: 1.0000e-04
# Epoch 143/200
# 6/6 [==============================] - 6s 978ms/step - loss: 0.1028 - val_loss: 0.1075 - lr: 1.0000e-04
# Epoch 144/200
# 6/6 [==============================] - 6s 985ms/step - loss: 0.1028 - val_loss: 0.1041 - lr: 1.0000e-04
# Epoch 145/200
# 6/6 [==============================] - 6s 968ms/step - loss: 0.1028 - val_loss: 0.1043 - lr: 1.0000e-04
# Epoch 146/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1028 - val_loss: 0.1038 - lr: 1.0000e-04
# Epoch 147/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1027 - val_loss: 0.1037 - lr: 1.0000e-04
# Epoch 148/200
# 6/6 [==============================] - 6s 985ms/step - loss: 0.1027 - val_loss: 0.1037 - lr: 1.0000e-04
# Epoch 149/200
# 6/6 [==============================] - 6s 979ms/step - loss: 0.1026 - val_loss: 0.1035 - lr: 1.0000e-04
# Epoch 150/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1026 - val_loss: 0.1041 - lr: 1.0000e-04
# Epoch 151/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1026 - val_loss: 0.1035 - lr: 1.0000e-04
# Epoch 152/200
# 6/6 [==============================] - 6s 984ms/step - loss: 0.1026 - val_loss: 0.1037 - lr: 1.0000e-04
# Epoch 153/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1027 - val_loss: 0.1037 - lr: 1.0000e-04
# Epoch 154/200
# 6/6 [==============================] - 6s 968ms/step - loss: 0.1026 - val_loss: 0.1032 - lr: 1.0000e-04
# Epoch 155/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1025 - val_loss: 0.1034 - lr: 1.0000e-04
# Epoch 156/200
# 6/6 [==============================] - 6s 1s/step - loss: 0.1025 - val_loss: 0.1031 - lr: 1.0000e-04
# Epoch 157/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1025 - val_loss: 0.1039 - lr: 1.0000e-04
# Epoch 158/200
# 6/6 [==============================] - 6s 971ms/step - loss: 0.1024 - val_loss: 0.1030 - lr: 1.0000e-04
# Epoch 159/200
# 6/6 [==============================] - 6s 983ms/step - loss: 0.1024 - val_loss: 0.1033 - lr: 1.0000e-04
# Epoch 160/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1024 - val_loss: 0.1036 - lr: 1.0000e-04
# Epoch 161/200
# 6/6 [==============================] - 6s 968ms/step - loss: 0.1025 - val_loss: 0.1028 - lr: 1.0000e-04
# Epoch 162/200
# 6/6 [==============================] - 6s 976ms/step - loss: 0.1024 - val_loss: 0.1028 - lr: 1.0000e-04
# Epoch 163/200
# 6/6 [==============================] - 6s 981ms/step - loss: 0.1023 - val_loss: 0.1031 - lr: 1.0000e-04
# Epoch 164/200
# 6/6 [==============================] - 6s 971ms/step - loss: 0.1023 - val_loss: 0.1037 - lr: 1.0000e-04
# Epoch 165/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1023 - val_loss: 0.1036 - lr: 1.0000e-04
# Epoch 166/200
# 6/6 [==============================] - 6s 969ms/step - loss: 0.1023 - val_loss: 0.1027 - lr: 1.0000e-04
# Epoch 167/200
# 6/6 [==============================] - 6s 986ms/step - loss: 0.1023 - val_loss: 0.1029 - lr: 1.0000e-04
# Epoch 168/200
# 6/6 [==============================] - 6s 978ms/step - loss: 0.1022 - val_loss: 0.1029 - lr: 1.0000e-04
# Epoch 169/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1022 - val_loss: 0.1037 - lr: 1.0000e-04
# Epoch 170/200
# 6/6 [==============================] - 6s 979ms/step - loss: 0.1022 - val_loss: 0.1026 - lr: 1.0000e-04
# Epoch 171/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1022 - val_loss: 0.1029 - lr: 1.0000e-04
# Epoch 172/200
# 6/6 [==============================] - 6s 971ms/step - loss: 0.1022 - val_loss: 0.1032 - lr: 1.0000e-05
# Epoch 173/200
# 6/6 [==============================] - 6s 971ms/step - loss: 0.1021 - val_loss: 0.1024 - lr: 1.0000e-05
# Epoch 174/200
# 6/6 [==============================] - 6s 976ms/step - loss: 0.1021 - val_loss: 0.1024 - lr: 1.0000e-05
# Epoch 175/200
# 6/6 [==============================] - 6s 981ms/step - loss: 0.1021 - val_loss: 0.1026 - lr: 1.0000e-05
# Epoch 176/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1021 - val_loss: 0.1023 - lr: 1.0000e-05
# Epoch 177/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1021 - val_loss: 0.1024 - lr: 1.0000e-05
# Epoch 178/200
# 6/6 [==============================] - 6s 979ms/step - loss: 0.1021 - val_loss: 0.1023 - lr: 1.0000e-05
# Epoch 179/200
# 6/6 [==============================] - 6s 979ms/step - loss: 0.1021 - val_loss: 0.1023 - lr: 1.0000e-06
# Epoch 180/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1021 - val_loss: 0.1023 - lr: 1.0000e-06
# Epoch 181/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1021 - val_loss: 0.1023 - lr: 1.0000e-06
# Epoch 182/200
# 6/6 [==============================] - 6s 978ms/step - loss: 0.1021 - val_loss: 0.1022 - lr: 1.0000e-06
# Epoch 183/200
# 6/6 [==============================] - 6s 982ms/step - loss: 0.1021 - val_loss: 0.1022 - lr: 1.0000e-06
# Epoch 184/200
# 6/6 [==============================] - 6s 992ms/step - loss: 0.1021 - val_loss: 0.1022 - lr: 1.0000e-06
# Epoch 185/200
# 6/6 [==============================] - 6s 978ms/step - loss: 0.1021 - val_loss: 0.1022 - lr: 1.0000e-06
# Epoch 186/200
# 6/6 [==============================] - 6s 976ms/step - loss: 0.1021 - val_loss: 0.1022 - lr: 1.0000e-07
# Epoch 187/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1021 - val_loss: 0.1022 - lr: 1.0000e-07
# Epoch 188/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1021 - val_loss: 0.1022 - lr: 1.0000e-07
# Epoch 189/200
# 6/6 [==============================] - 6s 967ms/step - loss: 0.1021 - val_loss: 0.1022 - lr: 1.0000e-07
# Epoch 190/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1021 - val_loss: 0.1021 - lr: 1.0000e-07
# Epoch 191/200
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1021 - val_loss: 0.1021 - lr: 1.0000e-07
# Epoch 192/200
# 6/6 [==============================] - 6s 975ms/step - loss: 0.1021 - val_loss: 0.1021 - lr: 1.0000e-07
# Epoch 193/200
# 6/6 [==============================] - 6s 970ms/step - loss: 0.1021 - val_loss: 0.1021 - lr: 1.0000e-08
# Epoch 194/200
# 6/6 [==============================] - 7s 1s/step - loss: 0.1021 - val_loss: 0.1021 - lr: 1.0000e-08
# Epoch 195/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1021 - val_loss: 0.1021 - lr: 1.0000e-08
# Epoch 196/200
# 6/6 [==============================] - 6s 972ms/step - loss: 0.1021 - val_loss: 0.1021 - lr: 1.0000e-08
# Epoch 197/200
# 6/6 [==============================] - 6s 976ms/step - loss: 0.1021 - val_loss: 0.1021 - lr: 1.0000e-08
# Epoch 198/200
# 6/6 [==============================] - 6s 980ms/step - loss: 0.1021 - val_loss: 0.1021 - lr: 1.0000e-09
# Epoch 199/200
# 6/6 [==============================] - 6s 969ms/step - loss: 0.1021 - val_loss: 0.1021 - lr: 1.0000e-09
# Epoch 200/200
# 6/6 [==============================] - 6s 967ms/step - loss: 0.1021 - val_loss: 0.1021 - lr: 1.0000e-09

# %%
# Select a random example from the validation dataset.
example = val_dataset[np.random.choice(range(len(val_dataset)), size=1)[0]]

# Pick the first/last ten frames from the example.
frames = example[:10, ...]
original_frames = example[10:, ...]

# Predict a new set of 10 frames.
for _ in range(10):
    # Extract the model's prediction and post-process it.
    new_prediction = model.predict(np.expand_dims(frames, axis=0))
    new_prediction = np.squeeze(new_prediction, axis=0)
    predicted_frame = np.expand_dims(new_prediction[-1, ...], axis=0)

    # Extend the set of prediction frames.
    frames = np.concatenate((frames, predicted_frame), axis=0)

# Construct a figure for the original and new frames.
fig, axes = plt.subplots(2, 10, figsize=(20, 4))

# Plot the original frames.
for idx, ax in enumerate(axes[0]):
    ax.imshow(np.squeeze(original_frames[idx]), cmap="gray")
    ax.set_title(f"Frame {idx + 11}")
    ax.axis("off")

# Plot the new frames.
new_frames = frames[10:, ...]
for idx, ax in enumerate(axes[1]):
    ax.imshow(np.squeeze(new_frames[idx]), cmap="gray")
    ax.set_title(f"Frame {idx + 11}")
    ax.axis("off")

# Display the figure.
plt.show()

# %%
# Select a few random examples from the dataset.
examples = val_dataset[np.random.choice(range(len(val_dataset)), size=5)]

# Iterate over the examples and predict the frames.
predicted_videos = []
for example in examples:
    # Pick the first/last ten frames from the example.
    frames = example[:10, ...]
    original_frames = example[10:, ...]
    new_predictions = np.zeros(shape=(10, *frames[0].shape))

    # Predict a new set of 10 frames.
    for i in range(10):
        # Extract the model's prediction and post-process it.
        frames = example[: 10 + i + 1, ...]
        new_prediction = model.predict(np.expand_dims(frames, axis=0))
        new_prediction = np.squeeze(new_prediction, axis=0)
        predicted_frame = np.expand_dims(new_prediction[-1, ...], axis=0)

        # Extend the set of prediction frames.
        new_predictions[i] = predicted_frame

    # Create and save GIFs for each of the ground truth/prediction images.
    for frame_set in [original_frames, new_predictions]:
        # Construct a GIF from the selected video frames.
        current_frames = np.squeeze(frame_set)
        current_frames = current_frames[..., np.newaxis] * np.ones(3)
        current_frames = (current_frames * 255).astype(np.uint8)
        current_frames = list(current_frames)

        # Construct a GIF from the frames.
        with io.BytesIO() as gif:
            imageio.mimsave(gif, current_frames, "GIF", fps=5)
            predicted_videos.append(gif.getvalue())

# Display the videos.
print(" Truth\tPrediction")
for i in range(0, len(predicted_videos), 2):
    # Construct and display an `HBox` with the ground truth and prediction.
    box = HBox(
        [
            widgets.Image(value=predicted_videos[i]),
            widgets.Image(value=predicted_videos[i + 1]),
        ]
    )
    display(box)
# Out:
#  Truth	Prediction
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\x7f\x7f\x7f\x00\x00\x00\x00\x00\x00\x00\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\x7f\x7f\x7f\x00\x00\x00\x00\x00\x00\x00\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\x7f\x7f\x7f\x00\x00\x00\x00\x00\x00\x00\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\x7f\x7f\x7f\x00\x00\x00\x00\x00\x00\x00\…
# HBox(children=(Image(value=b'GIF89a@\x00@\x00\x87\x00\x00\xff\xff\xff\x7f\x7f\x7f\x00\x00\x00\x00\x00\x00\x00\…
