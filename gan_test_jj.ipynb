# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/데이터공유폴더/dataset/cat_dog_dataset.zip

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation,ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam

import numpy as np
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt
import os
import time

GENERATE_RES = 3
GENERATE_SQUARE = 32 * GENERATE_RES
IMAGE_CHANNELS = 3

PREVIEW_ROWS = 4
PREVIEW_COLS = 7
PREVIEW_MARGIN = 16

SEED_SIZE = 100

DATA_PATH = '/content/training_set/cats'
EPOCHS = 100
BATCH_SIZE = 32
BUFFER_SIZE = 60000

print("will generate {generate_square} px square images.")
# Out:
# will generate {generate_square} px square images.

# %%
# !rm /content/training_set/cats/.DS_Store

# %%
os.makedirs('./gan_images_002')

# %%
training_binary_path = os.path.join(DATA_PATH,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATH)
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)

else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
# Looking for file: /content/training_set/cats/training_data_96_96.npy
# Loading training images...
# 100%|██████████| 4000/4000 [00:16<00:00, 238.01it/s]
# Saving training image binary...

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(training_data).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    model.add(UpSampling2D())
    model.add(Conv2D(128,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    if GENERATE_RES>1:
      model.add(UpSampling2D(size=(GENERATE_RES,GENERATE_RES)))
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    return model


def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
def save_images(cnt,noise):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)
  
  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] = generated_images[image_count] * 255
        image_count += 1

          
  output_path = os.path.join(DATA_PATH,'output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  
  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
generator = build_generator(SEED_SIZE, IMAGE_CHANNELS)

noise = tf.random.normal([1, SEED_SIZE])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[0.49967352]], shape=(1, 1), dtype=float32)

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)

# %%
@tf.function
def train_step(images):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(seed, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    

    gradients_of_generator = gen_tape.gradient(
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
def train(dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
  start = time.time()

  for epoch in range(epochs):
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for image_batch in dataset:
      t = train_step(image_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])

    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print (f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss},'
           ' {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed)

# %%
train(train_dataset, EPOCHS)
# Out:
# Epoch 1, gen loss=2.6051690578460693,disc loss=1.2117222547531128, {hms_string(epoch_elapsed)}
# Epoch 2, gen loss=3.4126787185668945,disc loss=1.0918256044387817, {hms_string(epoch_elapsed)}
# Epoch 3, gen loss=2.2286524772644043,disc loss=1.534881353378296, {hms_string(epoch_elapsed)}
# Epoch 4, gen loss=2.0215344429016113,disc loss=1.3279907703399658, {hms_string(epoch_elapsed)}
# Epoch 5, gen loss=1.7307124137878418,disc loss=1.5075993537902832, {hms_string(epoch_elapsed)}
# Epoch 6, gen loss=1.6756356954574585,disc loss=1.3329073190689087, {hms_string(epoch_elapsed)}
# Epoch 7, gen loss=1.8338143825531006,disc loss=1.3212039470672607, {hms_string(epoch_elapsed)}
# Epoch 8, gen loss=2.0590710639953613,disc loss=1.1615545749664307, {hms_string(epoch_elapsed)}
# Epoch 9, gen loss=2.0782344341278076,disc loss=1.209151029586792, {hms_string(epoch_elapsed)}
# Epoch 10, gen loss=2.301483631134033,disc loss=1.098273515701294, {hms_string(epoch_elapsed)}
# Epoch 11, gen loss=1.9114854335784912,disc loss=1.2927049398422241, {hms_string(epoch_elapsed)}
# Epoch 12, gen loss=1.669808268547058,disc loss=1.2672609090805054, {hms_string(epoch_elapsed)}
# Epoch 13, gen loss=1.8061487674713135,disc loss=1.3374152183532715, {hms_string(epoch_elapsed)}
# Epoch 14, gen loss=1.7556134462356567,disc loss=1.2167350053787231, {hms_string(epoch_elapsed)}
# Epoch 15, gen loss=1.8930412530899048,disc loss=1.1827502250671387, {hms_string(epoch_elapsed)}
# Epoch 16, gen loss=1.875752329826355,disc loss=1.2113832235336304, {hms_string(epoch_elapsed)}
# Epoch 17, gen loss=1.7672691345214844,disc loss=1.2530478239059448, {hms_string(epoch_elapsed)}
# Epoch 18, gen loss=1.682350993156433,disc loss=1.2082695960998535, {hms_string(epoch_elapsed)}
# Epoch 19, gen loss=1.7412983179092407,disc loss=1.229387640953064, {hms_string(epoch_elapsed)}
# Epoch 20, gen loss=1.7171046733856201,disc loss=1.156063199043274, {hms_string(epoch_elapsed)}
# Epoch 21, gen loss=1.7824169397354126,disc loss=1.1688389778137207, {hms_string(epoch_elapsed)}
# Epoch 22, gen loss=1.8582247495651245,disc loss=1.1980184316635132, {hms_string(epoch_elapsed)}
# Epoch 23, gen loss=1.628561019897461,disc loss=1.275334358215332, {hms_string(epoch_elapsed)}
# Epoch 24, gen loss=1.5808377265930176,disc loss=1.2782113552093506, {hms_string(epoch_elapsed)}
# Epoch 25, gen loss=1.6600793600082397,disc loss=1.2100412845611572, {hms_string(epoch_elapsed)}
# Epoch 26, gen loss=1.6122099161148071,disc loss=1.2014127969741821, {hms_string(epoch_elapsed)}
# Epoch 27, gen loss=1.6262235641479492,disc loss=1.2126270532608032, {hms_string(epoch_elapsed)}
# Epoch 28, gen loss=1.6458649635314941,disc loss=1.1913195848464966, {hms_string(epoch_elapsed)}
# Epoch 29, gen loss=1.6135565042495728,disc loss=1.2532570362091064, {hms_string(epoch_elapsed)}
# Epoch 30, gen loss=1.5822962522506714,disc loss=1.2051676511764526, {hms_string(epoch_elapsed)}
# Epoch 31, gen loss=1.8023940324783325,disc loss=1.1052274703979492, {hms_string(epoch_elapsed)}
# Epoch 32, gen loss=1.8080395460128784,disc loss=1.1572868824005127, {hms_string(epoch_elapsed)}
# Epoch 33, gen loss=1.6568278074264526,disc loss=1.1593087911605835, {hms_string(epoch_elapsed)}
# Epoch 34, gen loss=1.8585100173950195,disc loss=1.1260926723480225, {hms_string(epoch_elapsed)}
# Epoch 35, gen loss=1.777820110321045,disc loss=1.1464859247207642, {hms_string(epoch_elapsed)}
# Epoch 36, gen loss=1.7839471101760864,disc loss=1.1227366924285889, {hms_string(epoch_elapsed)}
# Epoch 37, gen loss=1.7629557847976685,disc loss=1.1394075155258179, {hms_string(epoch_elapsed)}
# Epoch 38, gen loss=1.929589867591858,disc loss=1.050806999206543, {hms_string(epoch_elapsed)}
# Epoch 39, gen loss=1.846319317817688,disc loss=1.1133079528808594, {hms_string(epoch_elapsed)}
# Epoch 40, gen loss=1.8325191736221313,disc loss=1.0622704029083252, {hms_string(epoch_elapsed)}
# Epoch 41, gen loss=1.826270341873169,disc loss=1.064884901046753, {hms_string(epoch_elapsed)}
# Epoch 42, gen loss=1.9431767463684082,disc loss=1.0615208148956299, {hms_string(epoch_elapsed)}
# Epoch 43, gen loss=2.243651866912842,disc loss=0.9510901570320129, {hms_string(epoch_elapsed)}
# Epoch 44, gen loss=1.9567562341690063,disc loss=1.0611482858657837, {hms_string(epoch_elapsed)}
# Epoch 45, gen loss=2.035759210586548,disc loss=1.0429805517196655, {hms_string(epoch_elapsed)}
# Epoch 46, gen loss=2.0801217555999756,disc loss=1.0566593408584595, {hms_string(epoch_elapsed)}
# Epoch 47, gen loss=2.0040297508239746,disc loss=1.0148415565490723, {hms_string(epoch_elapsed)}
# Epoch 48, gen loss=2.036754608154297,disc loss=1.0348280668258667, {hms_string(epoch_elapsed)}
# Epoch 49, gen loss=1.9074581861495972,disc loss=1.1174373626708984, {hms_string(epoch_elapsed)}
# Epoch 50, gen loss=1.9470489025115967,disc loss=1.0152701139450073, {hms_string(epoch_elapsed)}
# Epoch 51, gen loss=2.0335867404937744,disc loss=1.012230396270752, {hms_string(epoch_elapsed)}
# Epoch 52, gen loss=2.052424430847168,disc loss=0.9905187487602234, {hms_string(epoch_elapsed)}
# Epoch 53, gen loss=2.035102605819702,disc loss=0.9125049114227295, {hms_string(epoch_elapsed)}
# Epoch 54, gen loss=2.0136306285858154,disc loss=1.0317538976669312, {hms_string(epoch_elapsed)}
# Epoch 55, gen loss=2.0425617694854736,disc loss=1.0221412181854248, {hms_string(epoch_elapsed)}
# Epoch 56, gen loss=2.0062780380249023,disc loss=1.0274410247802734, {hms_string(epoch_elapsed)}
# Epoch 57, gen loss=2.05968976020813,disc loss=0.954700767993927, {hms_string(epoch_elapsed)}
# Epoch 58, gen loss=2.0313632488250732,disc loss=0.981910228729248, {hms_string(epoch_elapsed)}
# Epoch 59, gen loss=2.1203341484069824,disc loss=0.9475917220115662, {hms_string(epoch_elapsed)}
# Epoch 60, gen loss=2.1308374404907227,disc loss=0.9069085717201233, {hms_string(epoch_elapsed)}
# Epoch 61, gen loss=2.135141134262085,disc loss=0.9361556172370911, {hms_string(epoch_elapsed)}
# Epoch 62, gen loss=2.1416006088256836,disc loss=0.9438225030899048, {hms_string(epoch_elapsed)}
# Epoch 63, gen loss=2.3022453784942627,disc loss=0.9175265431404114, {hms_string(epoch_elapsed)}
# Epoch 64, gen loss=2.1970558166503906,disc loss=0.8560143113136292, {hms_string(epoch_elapsed)}
# Epoch 65, gen loss=2.451876401901245,disc loss=0.8945695757865906, {hms_string(epoch_elapsed)}
# Epoch 66, gen loss=2.3465771675109863,disc loss=0.8183656930923462, {hms_string(epoch_elapsed)}
# Epoch 67, gen loss=2.2661118507385254,disc loss=0.9277363419532776, {hms_string(epoch_elapsed)}
# Epoch 68, gen loss=2.263808250427246,disc loss=0.8443374633789062, {hms_string(epoch_elapsed)}
# Epoch 69, gen loss=2.3309545516967773,disc loss=0.8457387685775757, {hms_string(epoch_elapsed)}
# Epoch 70, gen loss=2.358670711517334,disc loss=0.8538104891777039, {hms_string(epoch_elapsed)}
# Epoch 71, gen loss=2.3968398571014404,disc loss=0.8706006407737732, {hms_string(epoch_elapsed)}
# Epoch 72, gen loss=2.4325218200683594,disc loss=0.8471716642379761, {hms_string(epoch_elapsed)}
# Epoch 73, gen loss=2.3711133003234863,disc loss=0.8218487501144409, {hms_string(epoch_elapsed)}
# Epoch 74, gen loss=2.4023215770721436,disc loss=0.8326405882835388, {hms_string(epoch_elapsed)}
# Epoch 75, gen loss=2.3858261108398438,disc loss=0.8325898051261902, {hms_string(epoch_elapsed)}
# Epoch 76, gen loss=2.4867632389068604,disc loss=0.8077911138534546, {hms_string(epoch_elapsed)}
# Epoch 77, gen loss=2.4205384254455566,disc loss=0.8946241140365601, {hms_string(epoch_elapsed)}
# Epoch 78, gen loss=2.3906733989715576,disc loss=0.7835561633110046, {hms_string(epoch_elapsed)}
# Epoch 79, gen loss=2.4848086833953857,disc loss=0.8298026919364929, {hms_string(epoch_elapsed)}
# Epoch 80, gen loss=2.4636707305908203,disc loss=0.8323695063591003, {hms_string(epoch_elapsed)}
# Epoch 81, gen loss=2.56508469581604,disc loss=0.8043901920318604, {hms_string(epoch_elapsed)}
# Epoch 82, gen loss=2.602994680404663,disc loss=0.7724043130874634, {hms_string(epoch_elapsed)}
# Epoch 83, gen loss=2.495276689529419,disc loss=0.8177598714828491, {hms_string(epoch_elapsed)}
# Epoch 84, gen loss=2.5412681102752686,disc loss=0.8456113338470459, {hms_string(epoch_elapsed)}
# Epoch 85, gen loss=2.529789924621582,disc loss=0.7671883702278137, {hms_string(epoch_elapsed)}
# Epoch 86, gen loss=2.584871292114258,disc loss=0.7697356343269348, {hms_string(epoch_elapsed)}
# Epoch 87, gen loss=2.650193214416504,disc loss=0.7626593708992004, {hms_string(epoch_elapsed)}
# Epoch 88, gen loss=2.6267144680023193,disc loss=0.7776534557342529, {hms_string(epoch_elapsed)}
# Epoch 89, gen loss=2.6153981685638428,disc loss=0.7813401818275452, {hms_string(epoch_elapsed)}
# Epoch 90, gen loss=2.6660611629486084,disc loss=0.7667230367660522, {hms_string(epoch_elapsed)}
# Epoch 91, gen loss=2.7990739345550537,disc loss=0.6887260675430298, {hms_string(epoch_elapsed)}
# Epoch 92, gen loss=2.8079748153686523,disc loss=0.7251765131950378, {hms_string(epoch_elapsed)}
# Epoch 93, gen loss=2.767289400100708,disc loss=0.7711501121520996, {hms_string(epoch_elapsed)}
# Epoch 94, gen loss=2.862712860107422,disc loss=0.8398908972740173, {hms_string(epoch_elapsed)}
# Epoch 95, gen loss=2.8503661155700684,disc loss=0.7794684767723083, {hms_string(epoch_elapsed)}
# Epoch 96, gen loss=2.773242950439453,disc loss=0.7365761399269104, {hms_string(epoch_elapsed)}
# Epoch 97, gen loss=2.9966816902160645,disc loss=0.6401299834251404, {hms_string(epoch_elapsed)}
# Epoch 98, gen loss=3.0767271518707275,disc loss=0.6438807249069214, {hms_string(epoch_elapsed)}
# Epoch 99, gen loss=2.9756343364715576,disc loss=0.6961162686347961, {hms_string(epoch_elapsed)}
# Epoch 100, gen loss=2.9083313941955566,disc loss=0.8195794820785522, {hms_string(epoch_elapsed)}

# %%
# !cp /content/training_set/cats/training_data_96_96.npy /content/drive/MyDrive/training_data_96_96.npy
